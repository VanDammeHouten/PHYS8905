# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### a)

# %% [markdown]
# ## Question 3
# ### a)
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# The CPTP map between a system $\mathcal{H}_Q$ and an environment $\mathcal{H}_E$ for a density operator $\rho_E$ acted on $\mathcal{H}_Q\otimes\mathcal{H}_E$ by a unitary operator $U$ can be expressed by:
# \begin{aligned}
#     M(\rho) &= \mathrm{tr}_{\mathcal{H}_E}(U(\rho\otimes\rho_E)U^{\dagger})
# \end{aligned}
#
# $\mathcal{H}_E$ has the basis $\ket{0}_E,\ket{1}_E,\ket{2}_E,\ket{3}_E$ and our system interacts with the environment according to the unitary $U_{QE}$.
#
# <!--
# \begin{aligned}
#     M(\rho) &= \sum_{k=0}^4 {}_{E}\bra{k}
#         U_{QE}
#         (\rho\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\ket{k}_E\\
#     \rho\otimes\ket{0}_E\bra{0} &=
#         U_{QE}
#         ((P_{00}\ket{0}\bra{0}
#         +  P_{01}\ket{0}\bra{1}
#         +  P_{10}\ket{1}\bra{0}
#         +  P_{11}\ket{1}\bra{1}
#         ))\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\\
#         &= U_{QE}
#         (P_{00}\ket{0}\bra{0}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\\
#         &+
#         U_{QE}
#         (P_{01}\ket{0}\bra{1}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\\
#         &+
#         U_{QE}
#         (P_{10}\ket{1}\bra{0}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\\
#         &+
#         U_{QE}
#         (P_{11}\ket{1}\bra{1}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\\
# \end{aligned}
#
# \begin{aligned}
# U_{QE}(P_{00}\ket{0}_Q\bra{0}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}
#     &= P_{00}U_{QE}\ket{0}_Q\ket{0}_E\bra{0}{}_Q\bra{0})U_{QE}^{\dagger}\\
#     &= P_{00}(\sqrt{1-p}\ket{0}_Q\ket{0}_E +\sqrt{p}\ket{0}_Q\ket{1}_E)\\
#         &+(\sqrt{1-p}\bra{0}_Q\bra{0}_E +\sqrt{p}\bra{0}_Q\bra{1}_E)\\
# U_{QE}(P_{01}\ket{0}_Q\bra{1}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}
#     &= P_{01}U_{QE}\ket{q}_Q\ket{0}_E\bra{0} {}_Q\bra{0}) U_{QE}^{\dagger}\\
#     &= P_{01}(\sqrt{1-p}\ket{0}_Q\ket{0}_E +\sqrt{p}\ket{0}_Q\ket{1}_E)\\
#         &+(\sqrt{1-p}\bra{1}_Q\bra{0}_E +\sqrt{p}\cos{\theta}\bra{0}_Q\bra{2}_E+
#         \sqrt{p}\sin{\theta}\bra{1}_Q\bra{3}_E)\\
# U_{QE}(P_{10}\ket{1}_Q\bra{0}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}
#     &= P_{10}U_{QE}\ket{1}_Q\ket{0}_E\bra{0} {}_Q\bra{0}) U_{QE}^{\dagger}\\
#     &= P_{10}(\sqrt{1-p}\ket{1}_Q\ket{0}_E +\sqrt{p}\cos{\theta}\ket{0}_Q\ket{2}_E+
#         \sqrt{p}\sin{\theta}\ket{1}_Q\ket{3}_E)\\
#         &+(\sqrt{1-p}\ket{0}_Q\ket{0}_E +\sqrt{p}\ket{0}_Q\ket{1}_E)\\
# U_{QE}(P_{11}\ket{1}_Q\bra{1}\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}
#     &= P_{11}U_{QE}\ket{1}_Q\ket{0}_E\bra{0} {}_Q\bra{1}) U_{QE}^{\dagger}\\
#     &= P_{11}(\sqrt{1-p}\ket{1}_Q\ket{0}_E +\sqrt{p}\cos{\theta}\ket{0}_Q\ket{2}_E+
#         \sqrt{p}\sin{\theta}\ket{1}_Q\ket{3}_E)\\
#         &+(\sqrt{1-p}\ket{0}_Q\ket{0}_E +\sqrt{p}\ket{0}_Q\ket{1}_E)
# \end{aligned}
#
# To calculate the Kraus operators showing only the terms that will contribute to each operator.
#
# \begin{aligned}
# M(\rho) &= \sum_{k=0}^4 {}_{E}\bra{k}
#         (
#             P_{00}(1-p)\ket{0}_Q\bra{0}\ket{0}_E\bra{0}
#             P_{00}p\ket{0}_Q\bra{0}\ket{1}_E\bra{1}
#             P_{01}(1-p)\ket{0}_Q\bra{1}\ket{0}_E\bra{0}
#             P_{01}(1-p)\ket{1}_Q\bra{0}\ket{0}_E\bra{0}
#
#         )
#
#
# M_0 &= {}_{E}\bra{0}
#         U_{QE}
#         (\rho\otimes\ket{0}_E\bra{0})
#         U_{QE}^{\dagger}\ket{0}_E
#     &= {}_{E}\bra{0}
#         P_{00}\sqrt{1-p}\ket{0}_Q\ket{0}_E
#         \sqrt{1-p}\bra{0}_Q\bra{0}_E
#         \ket{0}_E
# \end{aligned} -->

# %% [markdown]
# The partial trace over the environment can be reexpressed in its basis giving the CPTP map between a system and environment acted on by a unitary $U_{QE}$ as:
#
# $$
# \begin{aligned}
#     M(\rho) &= \sum_{k=0}^3 {}_{E}\bra{k}U_{QE}(\rho\otimes\rho_E)U_{QE}^{\dagger}\ket{k}_E
# \end{aligned}
# $$

# %% [markdown]
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# For the environment initialised in the pure state $\ket{\psi}_E$ the CPTP map becomes.
# $$
# \begin{aligned}
#     M(\rho) &= \sum_{k=0}^3 {}_{E}\bra{k}
#         U_{QE}
#         (\rho\otimes\ket{\psi}_E\bra{\psi})
#         U_{QE}^{\dagger}\ket{k}_E\\
#     &=\sum_{k=0}^3 {}_{E}\bra{k}
#         U_{QE}\ket{\psi}_E
#         \rho{}_E\bra{\psi}
#         U_{QE}^{\dagger}\ket{k}_E\\
# \end{aligned}
# $$

# %% [markdown]
# Thus the Kraus operators can be expressed as:
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# $$
# \begin{aligned}
#     M_\mu &= {}_E\bra{k}U_{QE}\ket{\psi}_E\\
# \end{aligned}
# $$

# %% [markdown]
# The coeffcients of an operator in a basis can be determined by the following:
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# $$
# \begin{aligned}
#     O_{j,k} &= \bra{j}O\ket{k}
# \end{aligned}
# $$

# %% [markdown]
# For our environment initialised in the state $\ket{0}_E$ the coefficients of the Kraus operators are found as follows:
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# $$
# \begin{aligned}
# M_{0_{0,0}} &= {}_Q\bra{0}{}_E\bra{0}U_{QE}\ket{0}_E\ket{0}_Q\\
#         &= \sqrt{1-p}\\
# M_{0_{1,1}} &= {}_Q\bra{1}{}_E\bra{0}U_{QE}\ket{0}_E\ket{1}_Q\\
#         &= \sqrt{1-p}\\
# M_{1_{0,0}} &= {}_Q\bra{0}{}_E\bra{1}U_{QE}\ket{0}_E\ket{0}_Q\\
#         &= \sqrt{p}\\
# M_{2_{0,1}} &= {}_Q\bra{0}{}_E\bra{2}U_{QE}\ket{0}_E\ket{1}_Q\\
#         &= \cos{\theta}\sqrt{p}\\
# M_{3_{1,1}} &= {}_Q\bra{1}{}_E\bra{3}U_{QE}\ket{0}_E\ket{1}_Q\\
#         &= \sin{\theta}\sqrt{p}
# \end{aligned}
# $$

# %% [markdown]
# These coefficients therefore form the following Kraus operators:
# $$
# \begin{aligned}
# M_0 &= \begin{pmatrix}
#     \sqrt{1-p} & 0\\
#     0 & \sqrt{1-p}
#     \end{pmatrix}\\
# M_1 &= \begin{pmatrix}
#     \sqrt{p} & 0\\
#     0 & 0
#     \end{pmatrix}\\
# M_2 &= \begin{pmatrix}
#     0 & \cos{\theta}\sqrt{p}\\
#     0 & 0
#     \end{pmatrix}\\
# M_3 &= \begin{pmatrix}
#     0 & 0\\
#     0 & \sin{\theta}\sqrt{p}
#     \end{pmatrix}\\
# \end{aligned}
# $$

# %% [markdown]
# ### b)
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# Let any density matrix in $\mathcal{H}_Q$ be expressed as the sum of basis vectors $\ket{0},\ket{1}$ with arbitrary complex coefficients such that:
#
# $$
#     \rho = P_{00}\ket{0}\bra{0}
#         +  P_{01}\ket{0}\bra{1}
#         +  P_{10}\ket{1}\bra{0}
#         +  P_{11}\ket{1}\bra{1}
# $$

# %% [markdown]
# The trace of the arbitrary matrix $\rho$ is:
# $$
# \mathrm{tr}(\rho) = P_{00} + P_{11}
# $$

# %% [markdown]
# The trace of the CPTP map applied to the density matrix $\rho$ is as follows:
# $$
# \begin{aligned}
#     M(\rho) &= \sum_{k=0}^3 M_k\rho M_k^{\dagger}\\
#     &= (1-p)\begin{pmatrix}
#     P_{0,0} & P_{0,1}\\
#     P_{1,0} & P_{1,1}
#     \end{pmatrix}
#     +p\begin{pmatrix}
#     P_{0,0} & 0\\
#     0 & 0
#     \end{pmatrix}
#     +\cos^2{\theta}p\begin{pmatrix}
#     P_{1,1} & 0\\
#     0 & 0
#     \end{pmatrix}
#     +\sin^2{\theta}p\begin{pmatrix}
#     0 & 0\\
#     0 & P_{1,1}
#     \end{pmatrix}\\
#     &=\begin{pmatrix}
#     P_{0,0} + \cos^2{\theta}pP_{1,1}& (1-p)P_{0,1}\\
#     (1-p)P_{0,1} & (1-p+\sin^2{\theta}p)P_{1,1}
#     \end{pmatrix}\\
#     &= \rho^{'}\\
# \mathrm{tr}(\rho^{'}) &=
#     P_{0,0} + \cos^2{\theta}pP_{1,1} + (1-p+\sin^2{\theta}p)P_{1,1}\\
#     &=P_{0,0} + P_{1,1}\\
#     &= \mathrm{tr}(\rho)
# \end{aligned}
# $$

# %% [markdown]
# ### c)
# The CPTP map applied successively $n$ times becomes:
# $$
# \begin{align}
#     S_{n}(\rho)
#     &=\begin{pmatrix}
#     P_{0,0} + (1-(1-p\cos^2{\theta})^n)P_{1,1}& (1-p)^nP_{0,1}\\
#     (1-p)^nP_{0,1} & (1-p\cos^2{\theta})^nP_{1,1}
#     \end{pmatrix}\\
# \end{align}
# $$
# This is critical as after $n$ time steps the trace is still preserved.

# %% [markdown]
# $\newcommand{\dt}{\delta t}$
# $\newcommand{\p}{\Gamma \dt}$
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# The map for small times $\dt$ where $p=\Gamma\dt \ll 1$ applied $n$ times is given as follows:
# $$
# \begin{align}
#     S_{n,\dt}(\rho)
#     &=\begin{pmatrix}
#     P_{0,0} + (1-(1-\p\cos^2{\theta})^n)P_{1,1}& (1-\p)^nP_{0,1}\\
#     (1-\p)^nP_{0,1} & (1-\p\cos^2{\theta})^nP_{1,1}
#     \end{pmatrix}\\
#     &=
#     \begin{pmatrix}
#         P_{0,0} + (1-\exp{(-\p n \cos^2{\theta})})P_{1,1}& \exp{(-\p n)}P_{0,1}\\
#         \exp{(-\p n)}P_{0,1} & \exp{(-\p n\cos^2{\theta})}P_{1,1}
#     \end{pmatrix}\\
# \end{align}
# $$

# %% [markdown]
# The continuous time version $S_{t}(\rho)$ is than the follows:
# $$
# \begin{align}
#     S_{t}(\rho)
#     &=
#     \begin{pmatrix}
#         P_{0,0} + (1-\exp{(-\Gamma t\cos^2{\theta})})P_{1,1}& \exp{(-\Gamma t)}P_{0,1}\\
#         \exp{(-\Gamma t)}P_{0,1} & \exp{(-\Gamma t\cos^2{\theta})}P_{1,1}
#     \end{pmatrix}\\
# \end{align}
# $$

# %% [markdown]
# ### d)
# For $\theta=\pi/2$ the continuous time CPTP map becomes:
# $$
# \begin{align}
#     S_{t}(\rho)
#     &=
#     \begin{pmatrix}
#         P_{0,0} & \exp{(-\Gamma t)}P_{0,1}\\
#         \exp{(-\Gamma t)}P_{0,1} & P_{1,1}
#     \end{pmatrix}\\
# \end{align}
# $$
# Which is exactly the pure phase damping map with rate $\Gamma$

# %% [markdown]
# ### e)
# For $\theta=0$ the continuous time CPTP map becomes:
# $$
# \begin{align}
#     S_{t}(\rho)
#     &=
#     \begin{pmatrix}
#         P_{0,0} + (1-\exp{(-\Gamma t)})P_{1,1}& \exp{(-\Gamma t)}P_{0,1}\\
#         \exp{(-\Gamma t)}P_{0,1} & \exp{(-\Gamma t)}P_{1,1}
#     \end{pmatrix}\\
# \end{align}
# $$
#
# With both amplitude and phase damping at rate $\Gamma$

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### a)
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
#
# The equation of motion in the interaction picture can be expressed as so:
#
# $$
# \begin{aligned}
#     \V &= e^{iHt}\\
#     \dot{\V} &= iH\V\\
#         &= i\V H\\
#     \rhoI &= \V \rho \V^{\dagger}\\
#     \drhoI &= \frac{d}{dt}\V \rho \V^{\dagger}\\
#     &= \dot{\V}\rho \V^{\dagger} + \V \drho \V^{\dagger} + \V \rho \dot{\V}^{\dagger}\\
#     &=\V iH\rho \V^{\dagger} + \V \drho \V^{\dagger} - \V \rho iH \V^{\dagger}\\
#     &= \V\left(
#         i\left[H,rho\right] + \drho
#     \right) \V^{\dagger}\\
#     &= \V\left(
#         i\left[H,rho\right]
#         - i\left[H,rho\right]
#         +\gamma(2\lower\rho\raise -\raise\lower\rho -\rho\raise\lower)
#     \right) \V^{\dagger}\\
#     &= \gamma\V
#         (2\lower\rho\raise -\raise\lower\rho -\rho\raise\lower)
#     \V^{\dagger}\\
#     &=
#     \gamma\left(2
#         {\lower}^{(I)}\rhoI{\raise}^{(I)}
#         -{\raise}^{(I)}{\lower}^{(I)}\rhoI
#         -\rhoI {\raise}^{(I)} {\lower}^{(I)}
#     \right)
# \end{aligned}
# $$

# %% [markdown]
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
#
# Since the Hamiltonian $H = \frac{-\omega \sigma_z}{2}$ is diagonal the interaction term $V(t)$ can be expressed by exponentiating each diagonal element.
#
#
# $$
# \begin{aligned}
#     \V &= e^{-i\omega\sigma_z t/2}\\
#     &= e^{-i\omega t/2}\ket{0}\bra{0} + e^{i\omega t/2}\ket{1}\bra{1}
# \end{aligned}
# $$

# %% [markdown]
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
#
# This allows the lowering and raising operators in the interaction picture to be expressed as shown.
# $$
# \begin{aligned}
#     {\lower}^{(I)} &= \V \lower \V{\dagger}\\
#     &= e^{iHt} \lower e^{-iHt}\\
#     &= e^{-i\omega t/2}\lower e^{-iHt}\\
#     &= e^{-i\omega t}\lower\\
#     {\raise}^{(I)} &= \V \raise \V{\dagger}\\
#     &= e^{iHt} \raise e^{-iHt}\\
#     &= e^{i\omega t/2}\raise e^{-iHt}\\
#     &= e^{i\omega t}\raise\\
# \end{aligned}
# $$

# %% [markdown]
# The equation of motion in the interaction picture can than be rewritten as:
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
# $$
# \begin{aligned}
# \drhoI &=
#     \gamma\left(2
#         {\lower}^{(I)}\rhoI{\raise}^{(I)}
#         -{\raise}^{(I)}{\lower}^{(I)}\rhoI
#         -\rhoI {\raise}^{(I)} {\lower}^{(I)}
#     \right)\\
# &=
#     \gamma\left(2
#         e^{-i\omega t}\lower\rhoI e^{i\omega t}\raise
#         -e^{i\omega t}\raise e^{-i\omega t}\lower\rhoI
#         -\rhoI e^{i\omega t}\raise e^{-i\omega t}\lower
#     \right)\\
# &=
#     \gamma\left(2
#         \lower\rhoI \raise
#         -\raise\lower\rhoI
#         -\rhoI\raise\lower
#     \right)
# \end{aligned}
# $$

# %% [markdown]
# ### b)
# The derivative of the Bloch vector notation of the time evolving density matrix in the interaction picture is.
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
# $$
# \begin{aligned}
# \rhoI(t)
#     &= \frac{1}{2}\left(
#         I + \lambdat{x}\sigma_x +\lambdat{y}\sigma_y +\lambdat{z}\sigma_z
#     \right)\\
# \drhoI(t)
#     &= \frac{1}{2}\left(
#         \dlambdat{x}\sigma_x +\dlambdat{y}\sigma_y +\dlambdat{z}\sigma_z
#     \right)
# \end{aligned}
# $$

# %% [markdown]
# Substituting it into the equation of motion derived above gives.
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
# $$
# \begin{aligned}
#     \drhoI(t) &=
#     \gamma\left(
#         \lower(1 + \lambdat{x}\sigma_x +\lambdat{y}\sigma_y +\lambdat{z}\sigma_z)\raise\\
#         -\frac{1}{2}\raise\lower(I + \lambdat{x}\sigma_x +\lambdat{y}\sigma_y +\lambdat{z}\sigma_z)\\
#         -\frac{1}{2}(1 + \lambdat{x}\sigma_x +\lambdat{y}\sigma_y +\lambdat{z}\sigma_z)\raise\lower
#     \right)\\
#     &= \gamma\left(
#         (1 - \lambdat{z})\ket{0}\bra{0}\\
#         -\frac{1}{2}((1 - \lambdat{z})\ket{1}\bra{1} +(\lambdat{x} + i\lambdat{y})\ket{1}\bra{0})\\
#         -\frac{1}{2}((1 - \lambdat{z})\ket{1}\bra{1} +(\lambdat{x} - i\lambdat{y})\ket{0}\bra{1})
#     \right)\\
#     &= \gamma\left(
#         \sigma_z - \lambdat{z}\sigma_z -\frac{1}{2}\lambdat{x}\sigma_x-\frac{1}{2}\lambdat{y}\sigma_y
#     \right)
# \end{aligned}
# $$

# %% [markdown]
# Equating the two equations gives:
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
#
# $$
#     \frac{1}{2}\left(
#         \dlambdat{x}\sigma_x +\dlambdat{y}\sigma_y +\dlambdat{z}\sigma_z
#     \right) =
#     \gamma\left(
#         \sigma_z - \lambdat{z}\sigma_z -\frac{1}{2}\lambdat{x}\sigma_x-\frac{1}{2}\lambdat{y}\sigma_y
#     \right)
# $$

# %% [markdown]
# Grouping operators gives the following set of ordinary differential equaitons:
#
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
# $$
# \begin{aligned}
#     \dlambdat{x} + \gamma\lambdat{x} &= 0\\
#     \dlambdat{y} + \gamma\lambdat{y} &= 0\\
#     \dlambdat{z} + 2\gamma\lambdat{z} &= 2\gamma
# \end{aligned}
# $$

# %% [markdown]
# Solving gives the following solutions:
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
# $$
# \begin{aligned}
# \lambdat{x} &= c_1 e^{-\gamma t}\\
# \lambdat{y} &= c_2 e^{-\gamma t}\\
# \lambdat{z} &= c_3 e^{-2\gamma t} + 1
# \end{aligned}
# $$

# %% [markdown]
# $\newcommand{\rhoI}[0]{{\rho}^{(I)}}$
# $\newcommand{\V}[0]{{V(t)}}$
# $\newcommand{\drho}[0]{\dot{\rho}}$
# $\newcommand{\drhoI}[0]{\dot{\rho}^{(I)}}$
# $\newcommand{\lower}[0]{\sigma^{-}}$
# $\newcommand{\raise}[0]{\sigma^{+}}$
# $\newcommand{\lambdat}[1]{\lambda_{#1}\left(t\right)}$
# $\newcommand{\dlambdat}[1]{\dot{\lambda}_{#1}\left(t\right)}$
#
# $$
# \begin{aligned}
# \rhoI(t) &= \frac{1}{2}\left(
#     1
#     +c_1 e^{-\gamma t}\sigma_x
#     + c_2 e^{-\gamma t}\sigma_y
#     + c_3 e^{-2\gamma t}\sigma_z
#     + \sigma_z
# \right)\\
# \rho(t) &= \V^{\dagger}\rhoI(t)\V\\
#     &= \V^{\dagger}\frac{1}{2} \left(
#     I
#     +c_1 e^{-\gamma t}\sigma_x
#     + c_2 e^{-\gamma t}\sigma_y
#     + c_3 e^{-2\gamma t}\sigma_z
#     + \sigma_z
#     \right)\V\\
#     &= \frac{1}{2}\V^{\dagger}
#         \begin{pmatrix}
#             2+ c_3 e^{-2\gamma t} & (c_1-ic_2)e^{-\gamma t}\\
#             (c_1+ic_2)e^{-\gamma t} & -c_3 e^{-2\gamma t}
#         \end{pmatrix}\V\\
#     &= \frac{1}{2}
#         \begin{pmatrix}
#         e^{i\omega t/2} & 0\\
#         0 & e^{-i\omega t/2}
#         \end{pmatrix}
#         \begin{pmatrix}
#             2+ c_3 e^{-2\gamma t} & (c_1-ic_2)e^{-\gamma t}\\
#             (c_1+ic_2)e^{-\gamma t} & -c_3 e^{-2\gamma t}
#         \end{pmatrix}
#         \begin{pmatrix}
#         e^{-i\omega t/2} & 0\\
#         0 & e^{i\omega t/2}
#         \end{pmatrix}\\
#     &= \frac{1}{2}
#         \begin{pmatrix}
#             (2+ c_3 e^{-2\gamma t}) & (c_1-ic_2)e^{-\gamma t}e^{i\omega t}\\
#             (c_1+ic_2)e^{-\gamma t}e^{-i\omega t} & -c_3 e^{-2\gamma t}
#         \end{pmatrix}
# \end{aligned}
# $$

# %% [markdown]
# ### c)
# $$
# \begin{aligned}
#     \rho(0) &= \frac{1}{2}\begin{pmatrix}
#         2+c_3 & c_1-ic_2\\
#         c_1+ic_2 & -c_3
#     \end{pmatrix}
# \end{aligned}
# $$

# %% [markdown]
# Define the Kraus operators as follows:
# $$
# \begin{aligned}
#     M_0 &= \begin{pmatrix}
#             1 & 0\\
#             0 & \sqrt{1-\zeta}
#         \end{pmatrix}\\
#     M_1 &= \begin{pmatrix}
#             0 & \sqrt{\zeta}\\
#             0 & 0
#         \end{pmatrix}
# \end{aligned}
# $$

# %% [markdown]
# The CPTP map than becomes:
#
# $$
# \begin{align}
#     \rho(t) &= M_0\rho(0)M_0^{\dagger} + M_1\rho(0)M_1^{\dagger}\\
#     &= \frac{1}{2}\begin{pmatrix}
#         \rho_{00}(0) & \sqrt{1-\zeta^*}\rho_{01}(0)\\
#         \sqrt{1-\zeta}\rho_{10}(0) & \sqrt{1-\zeta}\sqrt{1-\zeta^*}\rho_{11}(0)
#     \end{pmatrix}
#     + \frac{1}{2}\begin{pmatrix}
#         \sqrt{\zeta\zeta^*}\rho_{11}(0) & 0\\
#         0 & 0
#     \end{pmatrix}\\
#     &= \frac{1}{2}\begin{pmatrix}
#         \rho_{00}(0) + \sqrt{\zeta\zeta^*}\rho_{11}(0)& \sqrt{1-\zeta^*}\rho_{01}(0)\\
#         \sqrt{1-\zeta}\rho_{10}(0) & \sqrt{1-\zeta}\sqrt{1-\zeta^*}\rho_{11}(0)
#     \end{pmatrix}\\
#     &= \frac{1}{2}\begin{pmatrix}
#         2+c_3 - \sqrt{\zeta\zeta^*}c_3& \sqrt{1-\zeta^*}(c_1-ic_2)\\
#         \sqrt{1-\zeta}(c_1+ic_2) & -\sqrt{1-\zeta}\sqrt{1-\zeta^*}c_3
#     \end{pmatrix}\\
# \end{align}
# $$

# %% [markdown]
# Equating with the derivation in 4b)
#
# $$
# \begin{aligned}
# \sqrt{1-\zeta} &= e^{-\gamma t}e^{-i\omega t}\\
# \sqrt{1-\zeta^{*}} &= e^{-\gamma t}e^{+i\omega t}\\
# \sqrt{1-\zeta}\sqrt{1-\zeta^{*}} &= e^{-2\gamma t}\\
# \sqrt{\zeta\zeta^{*}} &= 1-e^{-2\gamma t}
# \end{aligned}
# $$

# %% [markdown]
# Substituting back in:
#
# $$
# \begin{align}
#     \rho(t)
#     &= \frac{1}{2}\begin{pmatrix}
#         2+c_3 - (1-e^{-2\gamma t})c_3& e^{-\gamma t}e^{+i\omega t}(c_1-ic_2)\\
#         e^{-\gamma t}e^{-i\omega t}(c_1+ic_2) & -e^{-2\gamma t}e^{-i\omega t}c_3
#     \end{pmatrix}\\
# \end{align}
# $$
# QED
